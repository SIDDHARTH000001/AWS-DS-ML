# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)
#
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# # Hands On
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# # create a studio > give studio name + workspace name
#
#
#
# # after completion delete following three
#
# # 1. goto emr server less delete the interactive serverless app under manager serverless app
#
# # 2. goto workspace delete studio workspace
#
# # 3. delete sudio
