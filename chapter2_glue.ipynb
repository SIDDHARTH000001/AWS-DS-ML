# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # in glue click for crawlers
#
# ![image.png](attachment:image.png)
#
#
#
# # add source
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # create new glue db
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # RUN Crawler > check the glue db
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # +=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=
# #    ETL
# # +=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=
#
#
# # JSON TO PARQUET
#
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)    ![image-3.png](attachment:image-3.png)   ![image-4.png](attachment:image-4.png)
#
# # ADD Details
#
# # SOURCE                 ____________________________         TARGET
# ![image-5.png](attachment:image-5.png)  ![image-6.png](attachment:image-6.png)

# %% [markdown]
# # Update the catalog
#
# ![image.png](attachment:image.png)
#
# # click-on-save > it will ask to create a IAM Role > goto IAM > create a ROLE  with follwing permissoin
#
# ![image-2.png](attachment:image-2.png)                         ![image-3.png](attachment:image-3.png)
#
#
# # ADD role to glue ETL
#
# ![image-4.png](attachment:image-4.png)
#
# # SAVE AND RUN
#
# ![image-5.png](attachment:image-5.png)
#
# # check RUN Details
#
# ![image-6.png](attachment:image-6.png)
#
# # if failed try editing scripts
#
# in this case
#
#
# ```
# from pyspark.sql.functions import col, coalesce
# from awsglue.dynamicframe import DynamicFrame  # Import DynamicFrame
#
# # Convert the DynamicFrame to Spark DataFrame
# df = AmazonS3_node1740462664402.toDF()
#
# # Handle the 'choice' type by extracting 'double' values and ensuring all are cast to 'double'
# df = df.withColumn("CHANGE", coalesce(col("CHANGE").getItem("double").cast("double"), col("CHANGE").getItem("int").cast("double"))) \
#        .withColumn("PRICE", coalesce(col("PRICE").getItem("double").cast("double"), col("PRICE").getItem("int").cast("double")))
#
# # Convert back to DynamicFrame
# AmazonS3_node1740462664402 = DynamicFrame.fromDF(df, glueContext)  # Ensure glueContext is defined
#
# # Apply Schema Mapping (make sure the types align correctly)
# ChangeSchema_node1740462791265 = ApplyMapping.apply(
#     frame=AmazonS3_node1740462664402,
#     mappings=[
#         ("CHANGE", "double", "CHANGE", "double"),
#         ("PRICE", "double", "PRICE", "double"),
#         ("TICKER_SYMBOL", "string", "TICKER_SYMBOL", "string"),
#         ("SECTOR", "string", "SECTOR", "string")
#     ],
#     transformation_ctx="ChangeSchema_node1740462791265"
# )
#
#
#
#
#
# ```
# # Once successful > check the target s3 bucket
#
# ![image-7.png](attachment:image-7.png)
#
# # open any file and run query
#
# ![image-8.png](attachment:image-8.png)
#
# # RESULT
# ![image-9.png](attachment:image-9.png)

# %% [markdown]
# # BREW

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# # search databrew > add name > new dataset > new dataset name > give source s3 bucket > create new iam role name > create
#
#
# # perform different data manipulation and create a job at the end and give the target save direcorty

# %% [markdown]
# # +=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=
# #    ATHENA
# # +=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=

# %% [markdown]
# # go to athena > create > select your database > you will see your table > click on hamburger > preview table > you will see your result
#
# # might need to create bucket for query
# ![image.png](attachment:image.png)
