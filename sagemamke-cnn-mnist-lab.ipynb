# %% [markdown]
# # goto sagemaker AI >> create a notebook instance

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # wait to change it to inservice from pending
# ![image.png](attachment:image.png)

# %% [markdown]
# # once ready open jupyter notebook
# ![image.png](attachment:image.png)

# %% [markdown]
# # upload files like keras-mnist-sagemaker.ipynb and mnist-train-cnn.py and run the jupyter file cell by cell

# %% [markdown]
# # at the end make sure stop the sageaker instance
