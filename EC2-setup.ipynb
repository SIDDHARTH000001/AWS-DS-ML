# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # search Deep Learning And choose instance type
# # you can read documentation for the instance you are selecting with given link
#
#
# # slect accordingly e.g you want tensorflow , pytorch or mxnet and see their supported instance type cpu/gpu
# ![image.png](attachment:image.png)
# # Once finalized then select the instance

# %% [markdown]
# # after pasting doc link click on the first release
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # after clicking select , you can look for the compute type according to budget by compare
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # once selected next section will be key pair which is actually how will this instance be accessed
#
# ![image-3.png](attachment:image-3.png)
# # putty is used widly in windows to connect to this aws instance
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # next is network section make it to private {my ip }
# ![image.png](attachment:image.png)

# %% [markdown]
# # click on launch instance
# ![image.png](attachment:image.png)

# %% [markdown]
# # once connect click on check puty key will be downloded
# # next  connect to instance
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # you can connect to your ec2 instance just via this
#
# ![image.png](attachment:image.png)
#
# # but if we want to run Jupyter notebook along with connection to ec2 instance we need a tunnel

# %% [markdown]
# # after creating the ec2 if it ask to make it in public subnet as above follow these steps
#
# # Internet Gateway attached to your VPC
# ![image-4.png](attachment:image-4.png)
#
#
# ![image.png](attachment:image.png)
#
#
#
# ![image-2.png](attachment:image-2.png)
#
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # download putty.exe {https://the.earth.li/~sgtatham/putty/latest/w64/putty.exe}
#
# # run
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # in SSH copy instance' public dns

# %% [markdown]
# # and copy to HOST
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # now goto ssh >> auth & select yout putyy key file
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # next click on tunnels & select port as 8888 and destination as localhost:8888
# # then add >> Open
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # you will see now type >> jupyter notebook
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # now you will see few links to your notebook >> paste into your browser
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # similiar thing can be run on browser
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # once done upload your notebook and play
# ![image.png](attachment:image.png)

# %% [markdown]
# # AFTER USING YOUR FILE
#
# # MUST TURN OF THE EC2 INSTACE >> AND QUIT
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # FROM PUTTY ALSO QUIT
# ![image.png](attachment:image.png)

# %% [markdown]
# # TERMINATE THE INSTANCE
#
# ![image.png](attachment:image.png)
